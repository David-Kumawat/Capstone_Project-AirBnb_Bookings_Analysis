# %% [markdown]
# <a href="https://colab.research.google.com/github/David-Kumawat/Capstone_Project-AirBnb_Bookings_Analysis/blob/main/Capstone_EDA_Project_AirBnb_Bookings_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project Name -** AirBnb Bookings Analysis

# %% [markdown]
# ##### **Project Type** - EDA (Exploratory Data Analysis)
# ##### **Contribution** - Individual

# %% [markdown]
# # **Project Summary-**

# %% [markdown]
# #####AirBnb Bookings Analysis project done by (1 member) which is me David Kumawat. In this project I got one csv file which is - AirBnb Bookings Analysis.
# #####First I import the required libraries which is - pandas, numpy, seaborn, matplotlib. After this, I mounted my drive on colab and copy the path. Then read the path with the use of read_csv() function. And then I store in a variable which is df. Then I check the data how is look like. And I print head & tail of my data. Then I check info of dataset and I found in dataset around 49000 observation and 16 columns available. In this 10 columns are numerical and leftover is categorical. After that I check duplicate values and null values.
# #####Then Printing data description and understand the data then I apply a function on dataframe. To get the unique values of dataframe in each column.
# #####**Data Wrangling** First I check null value and changed null value with 0 becuase in dataframe null value exists no sense. Then I drop some columns which will I won't use. Those are this - host_name, name, last_review. Then I create a copy of dataframe and checked the outliers in dataframe and I saw in column minimum_night is minimum night too mush high and it is a outlier which I found. Then I search on google how to remove outlier and after this i write a function who excludes the outlier. Then I used the boxplot for checking is it any outlier exists.
# ##### After this, i create a chart that shows correlation between columns. Then I solve some problem statements and visualize insights that I found from the problem statement. And I solved many problem statements after the solving problem statement I visualize the chart. And wrote some details of the chart

# %% [markdown]
# # **GitHub Link-**

# %% [markdown]
# https://github.com/David-Kumawat/Capstone_Project-AirBnb_Bookings_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## **Problem 1. On which location maximum number of listing.**
#
# ## **Problem 2. The Highest listing is done by a host.**
#
# ## **Problem 3. Which room type is highest listed on which location.**
# ## **Problem 4. Top 5 highest listing neighbourhood(area).**
# ## **Problem 5. What is the average price preferred by the customer for each neighbourhood_group and for each room_type(listing type).**
# ## **Problem 6. neighbourhood(area) with maximum average price.**
# ## **Problem 7. Top 10 Cheap neighbourhood**
# ## **Problem 8. Where is the highest room availability in neighbourhood_groups(location)**
# ## **Problem 9. Relation between price variable with another variable.**

# %% [markdown]
# # **Define Your Business Objective?**

# %% [markdown]
#  **Since 2018, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers and provides (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.**
#
#  **This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values.**
#
# **Explore and analyse the data to discover key understandings.**

# %% [markdown]
# ## **1. Know your data**

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Mounting Drive

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Loading dataset 

path = "/content/drive/MyDrive/Capstone Project/Airbnb NYC 2019.csv"
df = pd.read_csv(path)

# %%
# Inspecting the first five rows from the dataset

df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Inspecting the last five rows from the dataset

df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# Printing shape of the dataframe

print(df.shape)
# Out:
# (48895, 16)

# %%
# Information of the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# **This data not have any duplicate value**

# %%
# Dataset Duplicate Value Count

df.duplicated().sum()
# Out:
# 0

# %%
# Checking each columns for null values 

df.isnull().sum().sort_values(ascending=False)
# Out:
# last_review                       10052
# reviews_per_month                 10052
# host_name                            21
# name                                 16
# id                                    0
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the null values in dataframe by using heatmap


plt.figure(figsize=(10,6))
sns.heatmap(df.isna(),cmap="YlGnBu")
plt.show()

# %% [markdown]
# ###what did you know about your dataset?

# %% [markdown]
# **Answer:** In my dataset there are 48895 rows and 16 columns, Each rows contains different listing, My Dataset have 10 numerical and 6 categorical columns, Dataset some columns have null values. Columns ( id,host_id ) have unique id's

# %% [markdown]
# ## **2. Uderstanding Your Variables**

# %%
# Printing dataset columns

print(df.columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# description of the data

df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# # Variables Description

# %% [markdown]
# ###**Answer: 1.** In dataframe columns is used for represent element address.
# ###**2.**The minimum price is 0 which is unlikely
# ###**3.**The Maximum minimum_nights is 1250, which is not appropriate
# ###**4.**Last_review and reviews_per_month columns have same number NaN values and they are connected, hence when the data missing in last_review column the values in reviews_per_month also missing
# ###**5.**Columns price and minimum_nights also connected columns
# ###**6.**Id and host_id is independend columns
# ###**7.**Columns id, host_id, latitude, longitude, price, minimum_nights, number_of_reviews, review_per_month, calculated_host_listings_count, availability_365 this columns are numerical and Columns name, host_name, neighbourhood_group, neighbourhood, room_type, last_review this are categorical columns

# %% [markdown]
# ###Check unique value for each variable

# %%
# Checking all variable for unique value
# With this function we can check all unique values
pd.options.display.max_colwidth = 100

# applying lambda function to get the all unique values of all columns
df.apply(lambda col: col.unique())
# Out:
# id                                [2539, 2595, 3647, 3831, 5022, 5099, 5121, 5178, 5203, 5238, 5295, 5441, 5803, 6021, 6090, 6848,...
# name                              [Clean & quiet apt home by the park, Skylit Midtown Castle, THE VILLAGE OF HARLEM....NEW YORK !,...
# host_id                           [2787, 2845, 4632, 4869, 7192, 7322, 7356, 8967, 7490, 7549, 7702, 7989, 9744, 11528, 11975, 159...
# host_name                         [John, Jennifer, Elisabeth, LisaRoxanne, Laura, Chris, Garon, Shunichi, MaryEllen, Ben, Lena, Ka...
# neighbourhood_group                                                               [Brooklyn, Manhattan, Queens, Staten Island, Bronx]
# neighbourhood                     [Kensington, Midtown, Harlem, Clinton Hill, East Harlem, Murray Hill, Bedford-Stuyvesant, Hell's...
# latitude                          [40.64749, 40.75362, 40.80902, 40.68514, 40.79851, 40.74767, 40.68688, 40.76489, 40.80178, 40.71...
# ...

# %% [markdown]
# #**3. Data** **Wrangling**

# %% [markdown]
# ###Data Wrangling Code

# %%
# checking how many null values in dataframe

df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Columns like name, host_name, last_review are not important columns. therefore I am droping these columns

df.drop(['name','host_name','last_review'],axis=1,inplace=True)

# %%
# show

df.head()
# Out:
#      id  host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0  2539     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1  2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 2  3647     4632           Manhattan        Harlem  40.80902  -73.94190
# 3  3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4  5022     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %% [markdown]
# ###Now only null values exists in reviews_per_month column

# %%
# Replacing all null values with zero

df.replace(np.NaN,0,inplace=True)

# %%
# Again checking there is null value or not

df.isnull().sum()
# Out:
# id                                0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# description of the data

df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         7.029962          23.274466           1.090910
# std         20.510550          44.550582           1.597283
# ...

# %%
# The price column having zero which not appropriate. Therefore I am keeping only thoese obeservation which are not having any zero value in price column

df = df[df['price']>0]

# %%
# description of the data 

df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.888400e+04  4.888400e+04  48884.000000  48884.000000  48884.000000
# mean   1.901679e+07  6.762203e+07     40.728953    -73.952176    152.755053
# std    1.098432e+07  7.861666e+07      0.054532      0.046159    240.170260
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.470548e+06  7.817310e+06     40.690100    -73.983080     69.000000
# 50%    1.967574e+07  3.079257e+07     40.723080    -73.955685    106.000000
# 75%    2.915297e+07  1.074344e+08     40.763120    -73.936290    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48884.000000       48884.000000       48884.000000
# mean         7.029887          23.271991           1.090800
# std         20.512224          44.551331           1.597213
# ...

# %%
# Making a copy of dataframe

new_df = df.copy()

# %%
# ceating a function which will remove outlier

def outlier(df,ft):
  q1 = df[ft].quantile(0.25)
  q3 = df[ft].quantile(0.75)

  iqr = q3 - q1

  lower_bound = q1 - 1.5 * iqr
  upper_bound = q3 - 1.5 * iqr

  ls = df.index[(df[ft] < lower_bound) | (df[ft] > upper_bound)]
  return ls

# %%
# Storing all index of oulier value
 
index_list = []
for feature in ['minimum_nights']:
  index_list.extend(outlier(new_df,feature))

# %%
len(index_list)
# Out:
# 48884

# %% [markdown]
# This data is very unstructured I found most all indexes which are outliers if I remove outliers then I won't have sufficient data to analyze. therefore I'm not removing any outliers.

# %% [markdown]
# ###What all manipulations have you done and what insights you found

# %% [markdown]
# **Answer** First I create a copy of dataframe. Then check null values in dataframe, Then I replace this null value with zero, After that I found some columns which won't use, Therefore I drop those columns(name,host_name,last_review).

# %% [markdown]
# #**Data Visualization, Storytelling & Experimenting with charts : Understand the relationships between variables**

# %% [markdown]
# # Correlation between variables

# %% [markdown]
# ###From the below correlation matrix we come to know that the number_of_reviews and reviews_per_month are highly correlated variables as compared to other variable.

# %%
new_df.head()
# Out:
#      id  host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0  2539     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1  2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 2  3647     4632           Manhattan        Harlem  40.80902  -73.94190
# 3  3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4  5022     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
# I'm taking only those columns which are numerical

num_col = ['latitude','longitude','price','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']

# %%
# Fixing the size for chart
plt.figure(figsize=(10,8))

sns.heatmap(new_df[num_col].corr(), cmap="Spectral", square=True)

plt.title("Correlation between numeric variable")
plt.show()

# %% [markdown]
# Here we can see reviews_per_month and number_of_reviews are having highest correlation.

# %% [markdown]
# ### **Problem 1. On which location maximum number of listing.**

# %%
neighbourhood_group = new_df.groupby('neighbourhood_group')['id'].count().reset_index().rename(columns={'id':'count_of_listing'}).sort_values(by='count_of_listing',ascending=False)
neighbourhood_group
# Out:
#   neighbourhood_group  count_of_listing
# 2           Manhattan             21660
# 1            Brooklyn             20095
# 3              Queens              5666
# 0               Bronx              1090
# 4       Staten Island               373

# %%
# Visualization

plt.pie(neighbourhood_group['count_of_listing'],labels=neighbourhood_group['neighbourhood_group'],autopct="%.0f%%")
plt.title('Neighbourhood Groups')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer** The pie chart displays clear precipitation from the chart

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** In Brooklyn and Manhattan highest listings are. Need to focus on other neighbourhood_group

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** Gained insights telling the need to focus on those location which only having few listing. When the more listing happen in these location company would grow.

# %% [markdown]
# **Scatter Plot**

# %%
# Visualization

sns.set(rc={"figure.figsize":(12,6)})
sns.scatterplot(x=new_df['longitude'],y=new_df['latitude'],hue=df['neighbourhood_group'])
plt.title('Map of Neighbourhood Group Locations')
plt.show()

# %% [markdown]
# ###**Problem 2. The Highest listing is done by a host.**

# %%
# printing columns

print(new_df.columns)
# Out:
# Index(['id', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Only taking ten rows 

host_listing_df = new_df.host_id.value_counts().reset_index().rename(columns={"index":"host_id","host_id":"count_of_listing"}).head(10)
host_listing_df
# Out:
#      host_id  count_of_listing
# 0  219517861               327
# 1  107434423               232
# 2   30283594               121
# 3  137358866               103
# 4   12243051                96
# 5   16098958                96
# 6   61391963                91
# 7   22541573                87
# 8  200380610                65
# 9    7503643                52

# %%
# Fixing the size of chart
sns.set(rc={"figure.figsize":(14,6)})

# storing into variable
fig = sns.barplot(x='host_id',y='count_of_listing',data=host_listing_df)
fig.set_title("Hosts id with most listings")
fig.set_xlabel("Host Id's")
fig.set_ylabel("Count of Listings")
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** Barchart gives better understanding recognize patterns and trends

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** One host listed more then 175 listing

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** We need to suggest other host they would try to list more listing

# %% [markdown]
# ###**Problem 3. Which room type is highest listed on which location.**

# %%
# Getting dataframe which having all room counts based on location

listing_type = new_df.groupby(['neighbourhood_group','room_type'])['id'].count().unstack()
listing_type
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           651           60
# Brooklyn                        9558         10126          411
# Manhattan                      13198          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
#importing matplotlib.pyplot

import matplotlib.pyplot as plt

# %%
# Visualization

listing_type.plot(kind='bar')
plt.title("Room type and counts based on location")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** In this chart understanding more high rather than other chart.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** **1.** Listing of all home, apartment is the highest in Manhattan. While Brooklyn has private room listing at the highest though the Entire home and apt listing is not far awy.
#
# **2.** It can be observed Shared room have few listing in each location

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** This Chart give insight is we need to do marketing on shared room and also we need do marketing on those location which are only having few listing.

# %% [markdown]
# ###**Problem 4. Top 5 highest listing neighbourhood(areas).**

# %%
# printing head

new_df.head()
# Out:
#      id  host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0  2539     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1  2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 2  3647     4632           Manhattan        Harlem  40.80902  -73.94190
# 3  3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4  5022     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
# creating a dataframe which having maximum listings by area

max_listing_area = new_df.groupby('neighbourhood')['id'].count().reset_index().sort_values(by='id',ascending=False).head(5)
max_listing_area.rename(columns={'neighbourhood':'Neighbourhood','id':'Total_listings'},inplace=True)
max_listing_area
# Out:
#           Neighbourhood  Total_listings
# 214        Williamsburg            3919
# 13   Bedford-Stuyvesant            3710
# 94               Harlem            2658
# 28             Bushwick            2462
# 202     Upper West Side            1971

# %%
# Creating a visualization for neighbourhood(area) with highest listing
# Fixing the size
plt.figure(figsize=(10,6))

plt.bar(max_listing_area.Neighbourhood.values,max_listing_area.Total_listings.values,align='center')
plt.title('Bar plot for total listing in area')
plt.xlabel('Neighbourhood(Area)')
plt.ylabel('Count')
# plt.tight_layout()
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** Bar chart shows the comparison.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** Top five areas with highest listing

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** These areas are having highest listing. It's mean here lot of people come.

# %% [markdown]
# ###**Problem 5.What is the average price preferred by the customer for each neighbourhood_group and for each room type(listing type).**

# %%
# I am getting the average price for each room and for each neighbourhood_group(location) and store in a dataframe
avg_pref_price = new_df.groupby(['neighbourhood_group','room_type'])['price'].mean().reset_index()

#print the dataframe
avg_pref_price
# Out:
#    neighbourhood_group        room_type       price
# 0                Bronx  Entire home/apt  127.506596
# 1                Bronx     Private room   66.890937
# 2                Bronx      Shared room   59.800000
# 3             Brooklyn  Entire home/apt  178.346202
# 4             Brooklyn     Private room   76.545428
# 5             Brooklyn      Shared room   50.773723
# 6            Manhattan  Entire home/apt  249.257994
# 7            Manhattan     Private room  116.776622
# 8            Manhattan      Shared room   88.977083
# 9               Queens  Entire home/apt  147.050573
# 10              Queens     Private room   71.762456
# 11              Queens      Shared room   69.020202
# 12       Staten Island  Entire home/apt  173.846591
# 13       Staten Island     Private room   62.292553
# 14       Staten Island      Shared room   57.444444

# %%
# Creating a visualization for avg prices of each neighbourhood_group with different room types
pc = sns.barplot(data=avg_pref_price,x='neighbourhood_group',y='price',hue='room_type',palette='bright')
patches = pc.patches
for i in range(len(patches)):
  x = patches[i].get_x() + patches[i].get_width()/2
  y = patches[i].get_height()+.05
  pc.annotate('{:.1f}'.format(avg_pref_price.price[i]),(x,y),ha='center')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** Because barchart shows comparison.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** I got all room type avg price and for all location and Manhattan is the only which have highest avg.price in Entire home/apt

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** In Manhattan Private room is having highest avg.price. And it is too much. we need to check price are listed based on the neighbour_group(location) and room. This will inpect on our business. And lead to negative growth.

# %% [markdown]
# ###**Problem 6. neighbourhood(Area) with maximum average price.**

# %%
# By using groupby method will get neighbourhood with max average price
area_with_avg_price = new_df.groupby(['neighbourhood']).agg({'price':'mean'}).reset_index().sort_values(by='price')

# Changing name of dataframe columns 
area_with_avg_price.rename(columns={'price':'avg.price'},inplace=True)

# show
area_with_avg_price.sort_values(by='avg.price',ascending=False)
# Out:
#       neighbourhood   avg.price
# 82   Fort Wadsworth  800.000000
# 219         Woodrow  700.000000
# 197         Tribeca  490.638418
# 174        Sea Gate  487.857143
# 167       Riverdale  442.090909
# ..              ...         ...
# 141        New Dorp   57.000000
# 179       Soundview   53.466667
# 196         Tremont   51.545455
# 102     Hunts Point   50.500000
# 27      Bull's Head   47.333333
#
# [221 rows x 2 columns]

# %%
# Visualization
sns.barplot(data=area_with_avg_price[-10:],x='avg.price',y='neighbourhood')
plt.title('TOP 10 EXPENSIVE NEIGHBOURHOOD(AREA)')
plt.xlabel('Average price')
plt.ylabel('Neighbourhood')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** Barchart always helpfull when we do comparison.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** **Fort Wadsworth** is the neighbourhood which is most expensive neighbourhood. After that **Woodrow** is the most expensive neighbourhood.

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** We can suggest Fort Wadsworth to those customer who are searching for a big home and good areas.

# %% [markdown]
# ###**Problem 7. Top 10 Cheap Neighbourhood**

# %%
# Visualization
sns.barplot(x='avg.price',y='neighbourhood',data=area_with_avg_price[:10],color='b')
plt.title('Cheap Neighbourhood')
plt.xlabel('Average Price')
plt.ylabel('Neighbourhood')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** For show comparison.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** Bull's Head and Hunts Point is the cheapest neighbourhood.
# And New Drop, Bronxdale, New Dorp Beach, Grant city are the neighbourhoods thier prices are same.

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** If somebody searching for a cheap and low room_type we can suggest these listings on those. In this way host earns something and it also impacts positively the business. Because we are not losing any customer

# %% [markdown]
# ###**Problem 7. Where is the highest room availability in neighbourhood_groups.**

# %%
# printing head of dataframe
new_df.head()
# Out:
#      id  host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0  2539     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1  2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 2  3647     4632           Manhattan        Harlem  40.80902  -73.94190
# 3  3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4  5022     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
# Creating data frame
avai_neigh = new_df.groupby('neighbourhood_group')['availability_365'].count()

# Printing
avai_neigh
# Out:
# neighbourhood_group
# Bronx             1090
# Brooklyn         20095
# Manhattan        21660
# Queens            5666
# Staten Island      373
# Name: availability_365, dtype: int64

# %%
# signing explode
exp = [0.2,0,0,0.2,0.2]

# Visualization
avai_neigh.plot(kind='pie',autopct='%.0f%%',explode=exp)
plt.title('Room Availibility')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer** Here I need to show availability. I choose this chart because there you will find which neighborhood group(location) most of the availability have.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** Manhattan and Brooklyn here most of the time room is available.

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** Manhattan and Brooklyn is having most availability. But other neighbourhood_group not having mush availability. For the rush days we need to increase availability.

# %% [markdown]
# ###**Problem 8. Relation Between Price variable with another variable.**
# ###minimum_nights
# ###number_of_reviews
# ###reviews_per_month
# ###calculated_host_listings_count

# %%
# minimum_nights v/s price
sns.relplot(x='minimum_nights',y='price',data=new_df,col='room_type')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** This chart shows the relation between two continuous feature.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** I see in charts when the minimum_nights is increase price also decreaces. because may host like thier customer stay more days. But where minimum night is 1 or 2 there prices are high.

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** When customers only want to stay one day and he/she only find a high price, That time customer won't book any room. It may impact negative to business.

# %%
# number_of_reviews v/s price
sns.relplot(y='number_of_reviews',x='price',data=new_df,col='room_type')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** This chart shows the relation between two continuous feature.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** I can see these in chart where the price is low where number of reviews high, it mean customer only prefer those room,home which low price.

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** Need to focus on those room,home where price are medium and high. Because there only few people visit.

# %%
# reviews_per_month v/s price
sns.relplot(x='reviews_per_month',y='price',data=new_df,col='room_type')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# **Answer:** This chart shows the relation between two continuous feature.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** Where the price is low. Customer only visit there. That's way reviews per month also high.

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** Here need to focus on high price room,home because overthere only  few peoples visit. That'way we are not find any review on monthly bases.

# %%
# calculated_host_listings_count v/s price
sns.relplot(y='price',x='calculated_host_listings_count',data=new_df,hue='room_type')
plt.show()

# %% [markdown]
# ###1. Why did you pick the specific chart?

# %% [markdown]
# Answer: This chart shows the relation between two continuous feature.

# %% [markdown]
# ###2. what is /are insight(s) found from the chart?

# %% [markdown]
# **Answer:** Those host which have more then 10 room,home their price is low. where host only having 1/2 listing their price are high. because they want to earn money more. and I think their property is also expensive.

# %% [markdown]
# ### 3. Will the gained insights help creating a positive business impact?
# ###Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer:** This not insight does not impact business.

# %% [markdown]
# # **Solution to Business Objective**

# %% [markdown]
# ####What do you suggest the client to achieve Business Objective?
# Explain Briefly.

# %% [markdown]
# #####**Answer:**First need to focus on neighbourhood_group variable because here Bronx and Staten Island are having low listing and queens also. so these locations need to increase listings. because if on rush days on these locations will not having many rooms then customers would go on another platform. And it's not good for business.
# Second need to check this all-time room available or not. because customers want a room and AirBnb does not provide thier room. then it will affect business .

# %% [markdown]
# #**Conclusion**

# %% [markdown]
# ##1. We can see that Manhattan and Brooklyn have the most listing on Airbnb. And both locations visit a lot of customer.
# ##2. Host id 219517861 has done a lot of listing on Airbnb and it has a lot of properties.
# ##3. Room type(entire_home/apt,private_room) is the most listed on all of the location.
# ##4. Neighbourhood_group Brookyln Areas have most of the listings such as Williamsburg and Bedford-Stuyvesant
# ##5. In all neighbourhood_group the most expensive room_type is that entire_home, apt.
# ##6. Most expensive areas are Fort Wadsworth and Woodrow.
# ##7. As we know the highest room is listed in Manhattan and Brooklyn and room availability is also high in these locations.
